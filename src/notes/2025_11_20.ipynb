# %%
import os
import pandas as pd
import numpy as np
import yfinance as yfin

# %%
os.getcwd()
# Out:
# '/workspaces/market-data-acquisition-service/src/notes'

# %%
data = pd.read_csv("../../data/META.csv", index_col="Date")

# %%
avg = np.average(data.Volume)
# Out:
# np.float64(15268470.967741935)

# %%
data.Volume.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
labels = data.pct_change()

# %%
labels[0, 1, 2, 3]

# %%
pct.Close.count()
# Out:
# np.int64(216)

# %%
pct.Close.plot(kind="bar", figsize=(12, 8))
# Out:
# <Axes: xlabel='Date'>
